# %%
import pandas as pd
import numpy as np
import matplotlib as plt


#read line each line in csv file
df = pd.read_csv('card_train.csv', sep=";", quotechar='"')

#print table
print(df)
# Out:
#     card_id;disp_id;type;issued
# 0      1005;9285;classic;931107
# 1        104;588;classic;940119
# 2       747;4915;classic;940205
# 3         70;439;classic;940208
# 4       577;3687;classic;940215
# 5       377;2429;classic;940303
# 6        721;4680;junior;940405
# 7       437;2762;classic;940601
# 8       188;1146;classic;940619
# 9          13;87;classic;940629
# 10      732;4763;classic;940721
# 11      181;1066;classic;940819
# 12       384;2475;junior;940915
# 13      309;1946;classic;940919
# 14      478;3084;classic;941009
# 15      563;3589;classic;941021
# 16      369;2363;classic;941108
# 17      376;2428;classic;941110
# 18      483;3115;classic;941124
# 19       174;1039;junior;941204
# 20      658;4251;classic;941225
# 21       763;5138;junior;941230
# 22      778;5275;classic;950102
# 23     1039;9837;classic;950107
# 24       477;3082;junior;950116
# 25      168;1018;classic;950124
# 26       314;1999;junior;950127
# 27      468;3023;classic;950130
# ...

# %%
df.describe()
# Out:
#        card_id;disp_id;type;issued
# count                          177
# unique                         177
# top           13;87;classic;940629
# freq                             1

# %%
df.head()
# Out:
#   card_id;disp_id;type;issued
# 0    1005;9285;classic;931107
# 1      104;588;classic;940119
# 2     747;4915;classic;940205
# 3       70;439;classic;940208
# 4     577;3687;classic;940215

# %%
df
# Out:
#     card_id;disp_id;type;issued
# 0      1005;9285;classic;931107
# 1        104;588;classic;940119
# 2       747;4915;classic;940205
# 3         70;439;classic;940208
# 4       577;3687;classic;940215
# 5       377;2429;classic;940303
# 6        721;4680;junior;940405
# 7       437;2762;classic;940601
# 8       188;1146;classic;940619
# 9          13;87;classic;940629
# 10      732;4763;classic;940721
# 11      181;1066;classic;940819
# 12       384;2475;junior;940915
# 13      309;1946;classic;940919
# 14      478;3084;classic;941009
# 15      563;3589;classic;941021
# 16      369;2363;classic;941108
# 17      376;2428;classic;941110
# 18      483;3115;classic;941124
# 19       174;1039;junior;941204
# 20      658;4251;classic;941225
# 21       763;5138;junior;941230
# 22      778;5275;classic;950102
# 23     1039;9837;classic;950107
# 24       477;3082;junior;950116
# 25      168;1018;classic;950124
# 26       314;1999;junior;950127
# 27      468;3023;classic;950130
# ...
